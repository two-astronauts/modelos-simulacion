# %% [markdown]
# <a href="https://colab.research.google.com/github/two-astronauts/modelos-simulacion/blob/main/Represa_Montecarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

random.seed()
start_time = time.time()

unidadesAcumuladas = 1
anios = 15
meses = 12
unidadeDesechadas = 0
unidadesBajas = 0

# for anio in range(anios):
#   print(f'Año: {anio + 1}')

for mes in range(anios * meses):
  probabilidad = random.random()
  cantidad = 0

  if (mes != 0):
    if (probabilidad < 0.15):
      cantidad = 0
    elif (probabilidad < 0.50):
      cantidad = 1
    elif (probabilidad < 0.80):
      cantidad = 2
    else:
      cantidad = 3

  unidadesAcumuladas += cantidad

  print(f'Mes: {mes + 1} - Unidades sin ajustar:  {unidadesAcumuladas}')

  if (unidadesAcumuladas > 4):
    unidadeDesechadas += unidadesAcumuladas - 4
    unidadesAcumuladas = 4

  # print(f'Mes: {mes + 1} - Unidades ajustadas:  {unidadesAcumuladas}')

  if (unidadesAcumuladas == 1):
    unidadesBajas += 1

  if (unidadesAcumuladas > 2):
    unidadesAcumuladas -= 2
  elif (unidadesAcumuladas == 1):
    unidadesAcumuladas -= 1

print(f'Cantidad de unidades desechadas por exceso:  {unidadeDesechadas}')
print(f'Cantidad de generación de energia con una sola unidad:  {unidadesBajas}')

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Mes: 1 - Unidades sin ajustar:  1
# Mes: 2 - Unidades sin ajustar:  2
# Mes: 3 - Unidades sin ajustar:  4
# Mes: 4 - Unidades sin ajustar:  3
# Mes: 5 - Unidades sin ajustar:  2
# Mes: 6 - Unidades sin ajustar:  4
# Mes: 7 - Unidades sin ajustar:  3
# Mes: 8 - Unidades sin ajustar:  3
# Mes: 9 - Unidades sin ajustar:  2
# Mes: 10 - Unidades sin ajustar:  4
# Mes: 11 - Unidades sin ajustar:  5
# Mes: 12 - Unidades sin ajustar:  3
# Mes: 13 - Unidades sin ajustar:  2
# Mes: 14 - Unidades sin ajustar:  3
# Mes: 15 - Unidades sin ajustar:  4
# Mes: 16 - Unidades sin ajustar:  2
# Mes: 17 - Unidades sin ajustar:  5
# Mes: 18 - Unidades sin ajustar:  3
# Mes: 19 - Unidades sin ajustar:  3
# Mes: 20 - Unidades sin ajustar:  4
# Mes: 21 - Unidades sin ajustar:  2
# Mes: 22 - Unidades sin ajustar:  5
# Mes: 23 - Unidades sin ajustar:  3
# Mes: 24 - Unidades sin ajustar:  1
# Mes: 25 - Unidades sin ajustar:  1
# Mes: 26 - Unidades sin ajustar:  3
# Mes: 27 - Unidades sin ajustar:  2
# ...
